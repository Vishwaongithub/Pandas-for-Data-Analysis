# %% [markdown]
# 9️⃣ Data Exporting & Storage
# 📌 Saving and loading data efficiently

# %%
import pandas as pd
df=pd.read_csv('weather.csv')

# %%
df1=df[['City','Remarks','Weather_Condition','Date']]

df2=df[['Temperature_C','Humidity_%','Date']]

df3=pd.concat([df1,df2],axis=1)

# %%
df3.to_csv('file.csv', index=False)
# concatinated 2 dfs and then stored the df3 into a csv file.

# %%
df3.to_excel('file.xlsx', index=False)
#This will save the df3 into a excel file

# %%
pd.read_excel('file.xlsx')
#we can read the excel file using this command
# Out:
#            City      Remarks Weather_Condition        Date  Temperature_C  \
# 0      New York         Cold            Cloudy  2024-01-01            5.0
# 1   Los Angeles         Warm             Sunny  2024-01-02           12.0
# 2       Chicago          Wet             Rainy  2024-01-03            8.0
# 3       Houston  Clear Night             Clear  2024-01-04            NaN
# 4       Phoenix          Hot             Sunny  2024-01-05           20.0
# 5      New York         Cold            Cloudy  2024-01-06           15.0
# 6   Los Angeles         Warm             Sunny  2024-01-07           18.0
# 7       Chicago          Wet             Rainy  2024-01-08           22.0
# 8       Houston  Clear Night             Clear  2024-01-09            NaN
# 9       Phoenix          Hot             Sunny  2024-01-10           30.0
# 10     New York         Cold            Cloudy  2024-01-01            5.0
# 11  Los Angeles         Warm             Sunny  2024-01-02           12.0
# ...

# %%
df3 = df3.rename(columns={'Date.1': 'Date_Duplicate'})

# %%
df.to_parquet('file.parquet')
#saves the df to parquet file for big data
