# %% [markdown]
# 2️⃣ Data Cleaning & Preprocessing
# 📌 Handling missing, duplicate, and incorrect values

# %%
import pandas as pd

df=pd.read_csv('weather.csv')
df
# Out:
#           Date   Time         City  Temperature_C  Humidity_%  \
# 0   2024-01-01  08:00     New York            5.0          80
# 1   2024-01-02  12:00  Los Angeles           12.0          65
# 2   2024-01-03  16:00      Chicago            8.0          70
# 3   2024-01-04  20:00      Houston            NaN          55
# 4   2024-01-05  23:00      Phoenix           20.0          40
# 5   2024-01-06  08:00     New York           15.0          60
# 6   2024-01-07  12:00  Los Angeles           18.0          75
# 7   2024-01-08  16:00      Chicago           22.0          50
# 8   2024-01-09  20:00      Houston            NaN          45
# 9   2024-01-10  23:00      Phoenix           30.0          35
# 10  2024-01-01  08:00     New York            5.0          80
# 11  2024-01-02  12:00  Los Angeles           12.0          65
# 12  2024-01-03  16:00      Chicago            8.0          70
# 13  2024-01-04  20:00      Houston            NaN          55
# ...

# %%
df.isnull().sum()
#provide us with the count of null values in the dataset for all the columns
# Out:
# Date                 0
# Time                 0
# City                 0
# Temperature_C        3
# Humidity_%           0
# Wind_Speed_kmph      0
# Weather_Condition    0
# Precipitation_mm     0
# Air_Quality_Index    0
# UV_Index             0
# Is_Weekend           0
# Remarks              0
# dtype: int64

# %%
df['Temperature_C']=df['Temperature_C'].fillna(df['Temperature_C'].mean())
#Here we had null values in the "Temperature_C" column so we filled the missing vlaues with the mean,
#you can also fill it with other methods like forward fill (ffill) and backward fill(bfill)
#to know about them more visit the pandas fillna documentation

# %%
df.dropna()
#Thsi will drop or remove all the rows/columns with missing values
# Out:
#           Date   Time         City  Temperature_C  Humidity_%  \
# 0   2024-01-01  08:00     New York       5.000000          80
# 1   2024-01-02  12:00  Los Angeles      12.000000          65
# 2   2024-01-03  16:00      Chicago       8.000000          70
# 3   2024-01-04  20:00      Houston      15.294118          55
# 4   2024-01-05  23:00      Phoenix      20.000000          40
# 5   2024-01-06  08:00     New York      15.000000          60
# 6   2024-01-07  12:00  Los Angeles      18.000000          75
# 7   2024-01-08  16:00      Chicago      22.000000          50
# 8   2024-01-09  20:00      Houston      15.294118          45
# 9   2024-01-10  23:00      Phoenix      30.000000          35
# 10  2024-01-01  08:00     New York       5.000000          80
# 11  2024-01-02  12:00  Los Angeles      12.000000          65
# 12  2024-01-03  16:00      Chicago       8.000000          70
# 13  2024-01-04  20:00      Houston      15.294118          55
# ...

# %%
df.duplicated()
#This will identify the duplicates in the dataset
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# dtype: bool

# %%
df.drop_duplicates()
#This removes all the rows with the duplicate values
# Out:
#          Date   Time         City  Temperature_C  Humidity_%  Wind_Speed_kmph  \
# 0  2024-01-01  08:00     New York       5.000000          80               10
# 1  2024-01-02  12:00  Los Angeles      12.000000          65               15
# 2  2024-01-03  16:00      Chicago       8.000000          70               20
# 3  2024-01-04  20:00      Houston      15.294118          55                5
# 4  2024-01-05  23:00      Phoenix      20.000000          40               12
# 5  2024-01-06  08:00     New York      15.000000          60               14
# 6  2024-01-07  12:00  Los Angeles      18.000000          75               11
# 7  2024-01-08  16:00      Chicago      22.000000          50                9
# 8  2024-01-09  20:00      Houston      15.294118          45                8
# 9  2024-01-10  23:00      Phoenix      30.000000          35                7
#
#   Weather_Condition  Precipitation_mm  Air_Quality_Index  UV_Index  \
# ...

# %%
df.drop_duplicates()
#This removes all the rows with the duplicate values
# Out:
#          Date   Time         City  Temperature_C  Humidity_%  Wind_Speed_kmph  \
# 0  2024-01-01  08:00     New York              5          80               10
# 1  2024-01-02  12:00  Los Angeles             12          65               15
# 2  2024-01-03  16:00      Chicago              8          70               20
# 3  2024-01-04  20:00      Houston             15          55                5
# 4  2024-01-05  23:00      Phoenix             20          40               12
# 5  2024-01-06  08:00     New York             15          60               14
# 6  2024-01-07  12:00  Los Angeles             18          75               11
# 7  2024-01-08  16:00      Chicago             22          50                9
# 8  2024-01-09  20:00      Houston             15          45                8
# 9  2024-01-10  23:00      Phoenix             30          35                7
#
#   Weather_Condition  Precipitation_mm  Air_Quality_Index  UV_Index  \
# ...

# %%
df['Temperature_C'].dtype
# Out:
# dtype('float64')

# %%
df['Temperature_C']=df['Temperature_C'].astype(dtype=int)
df['Temperature_C'].dtype
#This astype() function changes the data type of a column, as you can see above the data type of 
# column temperature was float but after performing this the data type of column temperature became int
# Out:
# dtype('int32')

# %%
pd.to_datetime(df['Date'])
#This changes the column to datetime format
# Out:
# 0    2024-01-01
# 1    2024-01-02
# 2    2024-01-03
# 3    2024-01-04
# 4    2024-01-05
# 5    2024-01-06
# 6    2024-01-07
# 7    2024-01-08
# 8    2024-01-09
# 9    2024-01-10
# 10   2024-01-01
# 11   2024-01-02
# 12   2024-01-03
# 13   2024-01-04
# 14   2024-01-05
# 15   2024-01-06
# 16   2024-01-07
# 17   2024-01-08
# 18   2024-01-03
# 19   2024-01-08
# Name: Date, dtype: datetime64[ns]

# %%
df.replace('New York','N.Y')
#This function replaces the values in the columns as here i replaced New York with N.Y
# Out:
#           Date   Time         City  Temperature_C  Humidity_%  \
# 0   2024-01-01  08:00          N.Y            5.0          80
# 1   2024-01-02  12:00  Los Angeles           12.0          65
# 2   2024-01-03  16:00      Chicago            8.0          70
# 3   2024-01-04  20:00      Houston            NaN          55
# 4   2024-01-05  23:00      Phoenix           20.0          40
# 5   2024-01-06  08:00          N.Y           15.0          60
# 6   2024-01-07  12:00  Los Angeles           18.0          75
# 7   2024-01-08  16:00      Chicago           22.0          50
# 8   2024-01-09  20:00      Houston            NaN          45
# 9   2024-01-10  23:00      Phoenix           30.0          35
# 10  2024-01-01  08:00          N.Y            5.0          80
# 11  2024-01-02  12:00  Los Angeles           12.0          65
# 12  2024-01-03  16:00      Chicago            8.0          70
# 13  2024-01-04  20:00      Houston            NaN          55
# ...

# %%
df.rename(columns={'Temperature_C':'Temp_C'})
#Changes the column name, Temperature_C changed to Temp_C
# Out:
#           Date   Time         City  Temp_C  Humidity_%  Wind_Speed_kmph  \
# 0   2024-01-01  08:00     New York     5.0          80               10
# 1   2024-01-02  12:00  Los Angeles    12.0          65               15
# 2   2024-01-03  16:00      Chicago     8.0          70               20
# 3   2024-01-04  20:00      Houston     NaN          55                5
# 4   2024-01-05  23:00      Phoenix    20.0          40               12
# 5   2024-01-06  08:00     New York    15.0          60               14
# 6   2024-01-07  12:00  Los Angeles    18.0          75               11
# 7   2024-01-08  16:00      Chicago    22.0          50                9
# 8   2024-01-09  20:00      Houston     NaN          45                8
# 9   2024-01-10  23:00      Phoenix    30.0          35                7
# 10  2024-01-01  08:00     New York     5.0          80               10
# 11  2024-01-02  12:00  Los Angeles    12.0          65               15
# ...

# %%
def mean_wind(x):
    if pd.isna(x):
        return df['Wind_Speed_kmph'].mean()
    else:
        return x
df['Wind_Speed_kmph']=df['Wind_Speed_kmph'].apply(func=mean_wind)
df

# In this the apply() function is used to apply function to a column in the data frame
#here I created a function which will replace all the NaN values with the mean for the wind_speed_kmph column.
# Out:
#           Date   Time         City  Temperature_C  Humidity_%  \
# 0   2024-01-01  08:00     New York            5.0          80
# 1   2024-01-02  12:00  Los Angeles           12.0          65
# 2   2024-01-03  16:00      Chicago            8.0          70
# 3   2024-01-04  20:00      Houston            NaN          55
# 4   2024-01-05  23:00      Phoenix           20.0          40
# 5   2024-01-06  08:00     New York           15.0          60
# 6   2024-01-07  12:00  Los Angeles           18.0          75
# 7   2024-01-08  16:00      Chicago           22.0          50
# 8   2024-01-09  20:00      Houston            NaN          45
# 9   2024-01-10  23:00      Phoenix           30.0          35
# 10  2024-01-01  08:00     New York            5.0          80
# 11  2024-01-02  12:00  Los Angeles           12.0          65
# 12  2024-01-03  16:00      Chicago            8.0          70
# 13  2024-01-04  20:00      Houston            NaN          55
# ...
