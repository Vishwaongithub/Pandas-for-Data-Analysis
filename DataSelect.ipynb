# %% [markdown]
# 3️⃣ Data Selection & Filtering
# 📌 Extracting relevant data

# %%
import pandas as pd

df=pd.read_csv("weather.csv")
df
# Out:
#           Date   Time         City  Temperature_C  Humidity_%  \
# 0   2024-01-01  08:00     New York            5.0          80
# 1   2024-01-02  12:00  Los Angeles           12.0          65
# 2   2024-01-03  16:00      Chicago            8.0          70
# 3   2024-01-04  20:00      Houston            NaN          55
# 4   2024-01-05  23:00      Phoenix           20.0          40
# 5   2024-01-06  08:00     New York           15.0          60
# 6   2024-01-07  12:00  Los Angeles           18.0          75
# 7   2024-01-08  16:00      Chicago           22.0          50
# 8   2024-01-09  20:00      Houston            NaN          45
# 9   2024-01-10  23:00      Phoenix           30.0          35
# 10  2024-01-01  08:00     New York            5.0          80
# 11  2024-01-02  12:00  Los Angeles           12.0          65
# 12  2024-01-03  16:00      Chicago            8.0          70
# 13  2024-01-04  20:00      Houston            NaN          55
# ...

# %%
df[['City','Temperature_C']]
#You can select columns according to your need and that too multiple
# Out:
#            City  Temperature_C
# 0      New York            5.0
# 1   Los Angeles           12.0
# 2       Chicago            8.0
# 3       Houston            NaN
# 4       Phoenix           20.0
# 5      New York           15.0
# 6   Los Angeles           18.0
# 7       Chicago           22.0
# 8       Houston            NaN
# 9       Phoenix           30.0
# 10     New York            5.0
# 11  Los Angeles           12.0
# 12      Chicago            8.0
# 13      Houston            NaN
# 14      Phoenix           20.0
# 15     New York           15.0
# 16  Los Angeles           18.0
# 17      Chicago           22.0
# 18      Chicago            8.0
# 19      Chicago           22.0

# %%
df.loc[df['Weather_Condition']=='Rainy']
#loc function in pandas is a very powerful and useful function,
#we can filter, update, and can even work with conditions.
# Out:
#           Date   Time     City  Temperature_C  Humidity_%  Wind_Speed_kmph  \
# 2   2024-01-03  16:00  Chicago            8.0          70               20
# 7   2024-01-08  16:00  Chicago           22.0          50                9
# 12  2024-01-03  16:00  Chicago            8.0          70               20
# 17  2024-01-08  16:00  Chicago           22.0          50                9
# 18  2024-01-03  16:00  Chicago            8.0          70               20
# 19  2024-01-08  16:00  Chicago           22.0          50                9
#
#    Weather_Condition  Precipitation_mm  Air_Quality_Index  UV_Index  \
# 2              Rainy              10.0                 60         3
# 7              Rainy               5.0                 65         5
# 12             Rainy              10.0                 60         3
# 17             Rainy               5.0                 65         5
# 18             Rainy              10.0                 60         3
# ...

# %%
df.iloc[2]
#this iloc() function uses integer based indexing
# Out:
# Date                 2024-01-03
# Time                      16:00
# City                    Chicago
# Temperature_C               8.0
# Humidity_%                   70
# Wind_Speed_kmph              20
# Weather_Condition         Rainy
# Precipitation_mm           10.0
# Air_Quality_Index            60
# UV_Index                      3
# Is_Weekend                False
# Remarks                     Wet
# Name: 2, dtype: object

# %%
df[df['Weather_Condition']=='Rainy']
#This way you can filter the things that you need based on the conditions
# Out:
#           Date   Time     City  Temperature_C  Humidity_%  Wind_Speed_kmph  \
# 2   2024-01-03  16:00  Chicago            8.0          70               20
# 7   2024-01-08  16:00  Chicago           22.0          50                9
# 12  2024-01-03  16:00  Chicago            8.0          70               20
# 17  2024-01-08  16:00  Chicago           22.0          50                9
# 18  2024-01-03  16:00  Chicago            8.0          70               20
# 19  2024-01-08  16:00  Chicago           22.0          50                9
#
#    Weather_Condition  Precipitation_mm  Air_Quality_Index  UV_Index  \
# 2              Rainy              10.0                 60         3
# 7              Rainy               5.0                 65         5
# 12             Rainy              10.0                 60         3
# 17             Rainy               5.0                 65         5
# 18             Rainy              10.0                 60         3
# ...

# %%
df.query('Weather_Condition == "Rainy"')
#this function can also be used to filter out the data but in a SQL- like syntax
# Out:
#           Date   Time     City  Temperature_C  Humidity_%  Wind_Speed_kmph  \
# 2   2024-01-03  16:00  Chicago            8.0          70               20
# 7   2024-01-08  16:00  Chicago           22.0          50                9
# 12  2024-01-03  16:00  Chicago            8.0          70               20
# 17  2024-01-08  16:00  Chicago           22.0          50                9
# 18  2024-01-03  16:00  Chicago            8.0          70               20
# 19  2024-01-08  16:00  Chicago           22.0          50                9
#
#    Weather_Condition  Precipitation_mm  Air_Quality_Index  UV_Index  \
# 2              Rainy              10.0                 60         3
# 7              Rainy               5.0                 65         5
# 12             Rainy              10.0                 60         3
# 17             Rainy               5.0                 65         5
# 18             Rainy              10.0                 60         3
# ...
