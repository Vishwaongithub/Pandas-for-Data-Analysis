# %% [markdown]
# 🔟 Data Visualization (Pandas Built-in)
# 📌 Quick exploratory visualizations

# %%
import pandas as pd
df = pd.read_csv('weather.csv')

# %%
df['Temperature_C'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind='box')
# Out:
# <Axes: >

# %%
df.plot(y='Humidity_%', kind='line')
# Out:
# <Axes: >

# %%
df.plot(kind='scatter', x='Temperature_C', y='Humidity_%', title="Temperature vs Humidity", figsize=(8, 5), color='red')
# Out:
# <Axes: title={'center': 'Temperature vs Humidity'}, xlabel='Temperature_C', ylabel='Humidity_%'>
